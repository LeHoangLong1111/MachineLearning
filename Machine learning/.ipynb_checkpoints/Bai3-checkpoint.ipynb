# %%
import pandas as pd
import numpy as np 
df = pd.read_csv('abalone.data')  # read data
df.info()   # show type each colums
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-cbb285ec8f85> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.read_csv('abalone.data')  # read data
#       4 df.info()   # show type each colums
#       5 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File abalone.data does not exist: 'abalone.data'

# %%
dataset = df.values
X = dataset[:,:-1]   #fetures
Y = dataset[:,-1:]   #label

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
X[:,0]= LE.fit_transform(X[:,0])  # chuyen ki tu thanh encode

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)  # chuan hoa du lieu

# %%
from sklearn.model_selection import train_test_split # split data thanh train , valid , test set
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3) #test size = 30% and train size = 70%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)
#X_train (10 input features, 70% of full dataset)
#X_val (10 input features, 15% of full dataset)
#X_test (10 input features, 15% of full dataset)
#Y_train (1 label, 70% of full dataset)
#Y_val (1 label, 15% of full dataset)
#Y_test (1 label, 15% of full dataset)
X_train=np.asarray(X_train).astype(np.float64)   # chuyen thanh float tranh loi 
Y_train=np.asarray(Y_train).astype(np.float64) 
X_val=np.asarray(X_train).astype(np.float64) 
Y_val=np.asarray(Y_train).astype(np.float64)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential([Dense(32, activation='relu', input_shape=(8,)),
                    Dense(32, activation='relu'),  
                    Dense(1)])
# structure neural network : input layer( size =8) , hidden layer 1 ( size 32),hidden 2 ( size 32) , output 
# relu function : Rectified Linear Unit , dùng train nhanh hơn
model.compile(optimizer='sgd',  # stochastic gradient descent, với multip-class classification nên dùng 
              loss='MeanSquaredLogarithmicError',   
              metrics=['accuracy'])
         #dung binary_crossentropy thi ra loss nAN

# %%
hist = model.fit(X_train, Y_train, epochs=100,          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 92/92 [==============================] - 0s 3ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 92/92 [==============================] - 0s 2ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 92/92 [==============================] - 0s 1ms/step - loss: 2.8264 - accuracy: 0.0000e+00 - val_loss: 2.8264 - val_accuracy: 0.0000e+00
